# %%
import pandas as pd

# %%
df = pd.read_csv('../dados/consulta_cand_2016_CE.txt', 
                 encoding='ISO-8859-1', 
                 sep=';',
                 names=["DATA_GERACAO", "HORA_GERACAO", "ANO_ELEICAO", "NUM_TURNO",
                  "DESCRICAO_ELEICAO", "SIGLA_UF", "SIGLA_UE", "DESCRICAO_UE",
                  "CODIGO_CARGO", "DESCRICAO_CARGO", "NOME_CANDIDATO", 
                  "SEQUENCIAL_CANDIDATO", "NUMERO_CANDIDATO",
                  "CPF_CANDIDATO",
                  "NOME_URNA_CANDIDATO", "COD_SITUACAO_CANDIDATURA",
                  "DES_SITUACAO_CANDIDATURA", "NUMERO_PARTIDO", "SIGLA_PARTIDO",
                  "NOME_PARTIDO", "CODIGO_LEGENDA", "SIGLA_LEGENDA", 
                  "COMPOSICAO_LEGENDA", "NOME_LEGENDA", "CODIGO_OCUPACAO",
                  "DESCRICAO_OCUPACAO", "DATA_NASCIMENTO",
                  "NUM_TITULO_ELEITORAL_CANDIDATO", "IDADE_DATA_ELEICAO",
                  "CODIGO_SEXO", "DESCRICAO_SEXO", "COD_GRAU_INSTRUCAO",
                  "DESCRICAO_GRAU_INSTRUCAO", "CODIGO_ESTADO_CIVIL",
                  "DESCRICAO_ESTADO_CIVIL", "CODIGO_COR_RACA",
                  "DESCRICAO_COR_RACA", "CODIGO_NACIONALIDADE",
                  "DESCRICAO_NACIONALIDADE", "SIGLA_UF_NASCIMENTO",
                  "CODIGO_MUNICIPIO_NASCIMENTO", "NOME_MUNICIPIO_NASCIMENTO",
                  "DESPESA_MAX_CAMPANHA", "COD_SIT_TOT_TURNO", 
                  "DESC_SIT_TOT_TURNO", "NM_EMAIL"])

# %%
df.head()
# Out:
#   DATA_GERACAO HORA_GERACAO  ANO_ELEICAO  NUM_TURNO         DESCRICAO_ELEICAO  \
# 0   09/09/2016     19:31:13         2016          1  Eleições Municipais 2016
# 1   09/09/2016     19:31:13         2016          1  Eleições Municipais 2016
# 2   09/09/2016     19:31:13         2016          1  Eleições Municipais 2016
# 3   09/09/2016     19:31:13         2016          1  Eleições Municipais 2016
# 4   09/09/2016     19:31:13         2016          1  Eleições Municipais 2016
#
#   SIGLA_UF  SIGLA_UE           DESCRICAO_UE  CODIGO_CARGO DESCRICAO_CARGO  \
# 0       CE     15512  SÃO JOÃO DO JAGUARIBE            13        VEREADOR
# 1       CE     15512  SÃO JOÃO DO JAGUARIBE            13        VEREADOR
# 2       CE     15512  SÃO JOÃO DO JAGUARIBE            13        VEREADOR
# 3       CE     14931                PACAJUS            13        VEREADOR
# 4       CE     14931                PACAJUS            13        VEREADOR
#
#              ...            DESCRICAO_COR_RACA  CODIGO_NACIONALIDADE  \
# 0            ...                         PRETA                     1
# 1            ...                         PRETA                     1
# 2            ...                         PARDA                     1
# 3            ...                         PARDA                     1
# 4            ...                         PRETA                     1
#
#    DESCRICAO_NACIONALIDADE  SIGLA_UF_NASCIMENTO CODIGO_MUNICIPIO_NASCIMENTO  \
# 0          BRASILEIRA NATA                   CE                          -3
# 1          BRASILEIRA NATA                   CE                          -3
# 2          BRASILEIRA NATA                   CE                          -3
# 3          BRASILEIRA NATA                   CE                          -3
# 4          BRASILEIRA NATA                   CE                          -3
#
#    NOME_MUNICIPIO_NASCIMENTO DESPESA_MAX_CAMPANHA  COD_SIT_TOT_TURNO  \
# 0      SAO JOAO DO JAGUARIBE                   -1                 -1
# 1      SAO JOAO DO JAGUARIBE                   -1                 -1
# 2      SAO JOAO DO JAGUARIBE                   -1                 -1
# 3                    PACAJUS                   -1                 -1
# 4                    PACAJUS                   -1                 -1
#
#   DESC_SIT_TOT_TURNO                  NM_EMAIL
# 0             #NULO#  AGORAEAVEZ2016@GMAIL.COM
# 1             #NULO#  AGORAEAVEZ2016@GMAIL.COM
# 2             #NULO#  AGORAEAVEZ2016@GMAIL.COM
# 3             #NULO#  ODILONAGUIAR37@GMAIL.COM
# 4             #NULO#  ODILONAGUIAR37@GMAIL.COM
#
# [5 rows x 46 columns]
